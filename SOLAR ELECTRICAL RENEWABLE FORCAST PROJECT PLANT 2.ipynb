# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # PLANT 2

# %%
generation_data_Plant_2 = pd.read_csv("Plant_2_Generation_Data.csv")

generation_data_Plant_2.sample(10)
# Out:
#                  DATE_TIME  PLANT_ID       SOURCE_KEY     DC_POWER  \
# 9197   2020-05-19 08:45:00   4136001  81aHJ1q11NBPMrL   336.006667
# 31283  2020-05-31 17:30:00   4136001  q49J1IKaHRwDQnt    81.200000
# 48114  2020-06-08 17:15:00   4136001  rrq4fwE8jgrTyWY   264.893333
# 17251  2020-05-24 01:30:00   4136001  Et9kgGMDl729KT4     0.000000
# 28931  2020-05-30 14:45:00   4136001  vOuJvMaM2sgwLmb  1022.426667
# 14867  2020-05-22 16:15:00   4136001  oZZkBaNadn6DNKz   623.860000
# 55305  2020-06-12 03:00:00   4136001  oZ35aAeoifZaQzV     0.000000
# 8572   2020-05-19 01:30:00   4136001  mqwcsP2rE7J0TFp     0.000000
# 6360   2020-05-18 00:30:00   4136001  9kRcWv60rDACzjR     0.000000
# 30840  2020-05-31 12:30:00   4136001  mqwcsP2rE7J0TFp   804.760000
#
#          AC_POWER  DAILY_YIELD   TOTAL_YIELD
# 9197   329.993333   800.600000  1.215297e+09
# 31283   78.780000  6299.800000  4.442518e+05
# 48114  259.780000  3253.333333  1.210911e+08
# 17251    0.000000     0.000000  1.743717e+06
# 28931  999.213333  4760.000000  2.324859e+06
# 14867  611.206667  9149.133333  1.708128e+09
# 55305    0.000000  3963.000000  1.660165e+09
# 8572     0.000000     0.000000  5.936120e+08
# 6360     0.000000     0.000000  2.247743e+09
# 30840  786.580000  3594.866667  5.937097e+08

# %%
weather_sensor_data_Plant_2 = pd.read_csv("Plant_2_Weather_Sensor_Data.csv")

weather_sensor_data_Plant_2.sample(10)
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 975   2020-05-25 04:15:00   4136001  iq8k7ZNt4Mwm3w0            25.253450
# 1207  2020-05-27 14:15:00   4136001  iq8k7ZNt4Mwm3w0            35.657429
# 1800  2020-06-02 19:00:00   4136001  iq8k7ZNt4Mwm3w0            27.649507
# 2195  2020-06-06 22:00:00   4136001  iq8k7ZNt4Mwm3w0            25.177572
# 955   2020-05-24 23:15:00   4136001  iq8k7ZNt4Mwm3w0            27.093005
# 2882  2020-06-14 01:45:00   4136001  iq8k7ZNt4Mwm3w0            24.412603
# 2155  2020-06-06 12:00:00   4136001  iq8k7ZNt4Mwm3w0            31.962851
# 111   2020-05-16 04:00:00   4136001  iq8k7ZNt4Mwm3w0            24.145103
# 3110  2020-06-16 10:45:00   4136001  iq8k7ZNt4Mwm3w0            28.663846
# 2486  2020-06-09 22:45:00   4136001  iq8k7ZNt4Mwm3w0            26.059422
#
#       MODULE_TEMPERATURE  IRRADIATION
# 975            23.613888     0.000000
# 1207           57.160799     0.770715
# 1800           26.337869     0.000000
# 2195           23.724282     0.000000
# 955            25.684797     0.000000
# 2882           23.533722     0.000000
# 2155           47.906496     0.767899
# 111            21.844981     0.000000
# 3110           39.306931     0.473544
# 2486           24.828207     0.000000

# %% [markdown]
# # Merged Two File into One File

# %% [markdown]
# Convert Date_TIME column into datetime format

# %%
generation_data_Plant_2['DATE_TIME'] = pd.to_datetime(generation_data_Plant_2['DATE_TIME'], format='%Y-%m-%d %H:%M:%S')

weather_sensor_data_Plant_2['DATE_TIME'] = pd.to_datetime(weather_sensor_data_Plant_2['DATE_TIME'], format='%Y-%m-%d %H:%M:%S')

# %%
generation_data_Plant_2__DATETIME_dtype = generation_data_Plant_2['DATE_TIME'].dtypes
weather_sensor_data_Plant_2_DATETIME_dtype = weather_sensor_data_Plant_2['DATE_TIME'].dtypes

print("Data type of Generation Data Plant 2 of Date_Time column:", generation_data_Plant_2__DATETIME_dtype)
print("Data type of Weather Sensor data Plant 2 of Date_Time column:", weather_sensor_data_Plant_2_DATETIME_dtype)
# Out:
# Data type of Generation Data Plant 2 of Date_Time column: datetime64[ns]
# Data type of Weather Sensor data Plant 2 of Date_Time column: datetime64[ns]

# %%
#merge the file

plant_2 = pd.merge(generation_data_Plant_2, weather_sensor_data_Plant_2, on='DATE_TIME')

# %%
plant_2.sample(10)
# Out:
#                 DATE_TIME  PLANT_ID_x     SOURCE_KEY_x     DC_POWER  \
# 31188 2020-05-31 16:30:00     4136001  Qf4GUc1pJu5T6c6   196.580000
# 57833 2020-06-13 07:45:00     4136001  WcxssY2VbP4hApt   288.153333
# 17124 2020-05-23 23:45:00     4136001  9kRcWv60rDACzjR     0.000000
# 1187  2020-05-15 13:15:00     4136001  xoJJ8DcxJEcupym     0.000000
# 36487 2020-06-03 05:00:00     4136001  Mx2yZCDsyf6DPfv     0.000000
# 1271  2020-05-15 14:15:00     4136001  q49J1IKaHRwDQnt  1023.746667
# 63598 2020-06-16 01:15:00     4136001  mqwcsP2rE7J0TFp     0.000000
# 38397 2020-06-04 03:00:00     4136001  Et9kgGMDl729KT4     0.000000
# 16234 2020-05-23 11:15:00     4136001  oZ35aAeoifZaQzV  1286.273333
# 48321 2020-06-08 19:45:00     4136001  LYwnQax7tkwH5Cb     0.000000
#
#           AC_POWER  DAILY_YIELD   TOTAL_YIELD  PLANT_ID_y     SOURCE_KEY_y  \
# 31188   192.700000  6449.600000  8.385500e+08     4136001  iq8k7ZNt4Mwm3w0
# 57833   282.766667   275.200000  1.818818e+08     4136001  iq8k7ZNt4Mwm3w0
# 17124     0.000000  4543.000000  2.247778e+09     4136001  iq8k7ZNt4Mwm3w0
# 1187      0.000000  1735.000000  2.091453e+08     4136001  iq8k7ZNt4Mwm3w0
# 36487     0.000000     0.000000  2.597257e+06     4136001  iq8k7ZNt4Mwm3w0
# 1271   1000.420000  7105.866667  3.470289e+05     4136001  iq8k7ZNt4Mwm3w0
# 63598     0.000000     0.000000  5.938052e+08     4136001  iq8k7ZNt4Mwm3w0
# 38397     0.000000     0.000000  1.808470e+06     4136001  iq8k7ZNt4Mwm3w0
# 16234  1254.126667  3662.333333  1.660032e+09     4136001  iq8k7ZNt4Mwm3w0
# 48321     0.000000  2702.000000  1.795074e+09     4136001  iq8k7ZNt4Mwm3w0
#
#        AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 31188            29.412227           31.889498     0.125894
# 57833            24.563085           29.497889     0.206715
# 17124            26.758631           25.310332     0.000000
# 1187             36.939564           56.859504     0.904247
# 36487            23.974262           23.518232     0.000000
# 1271             37.352829           53.538947     0.826129
# 63598            23.882562           22.922873     0.000000
# 38397            23.473554           22.322989     0.000000
# 16234            34.156459           56.555210     0.948992
# 48321            28.871325           27.222312     0.000000

# %%
plant_2 = plant_2.drop(columns=['PLANT_ID_x', 'PLANT_ID_y', 'SOURCE_KEY_y'])

plant_2 = plant_2.rename(columns={'SOURCE_KEY_x': 'SOURCE_KEY'})
plant_2.sample(5)
# Out:
#                 DATE_TIME       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 16876 2020-05-23 20:15:00  Mx2yZCDsyf6DPfv      0.00      0.00  9655.000000
# 19752 2020-05-25 12:15:00  9kRcWv60rDACzjR   1255.66   1224.26  4508.533333
# 14012 2020-05-22 04:30:00  LYwnQax7tkwH5Cb      0.00      0.00     0.000000
# 18554 2020-05-24 19:30:00  V94E5Ben1TlhnDV      0.00      0.00  9263.000000
# 55215 2020-06-12 02:00:00  WcxssY2VbP4hApt      0.00      0.00  3947.000000
#
#         TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 16876  2.526030e+06            31.585262           30.234904     0.000000
# 19752  2.247791e+09            34.030982           55.331840     0.907799
# 14012  1.794991e+09            23.491023           21.728595     0.000000
# 18554  1.412159e+09            32.586456           31.161048     0.000000
# 55215  1.818767e+08            22.752443           22.362240     0.000000

# %%
# split datetime column into date and time

plant_2['DATE'] = plant_2['DATE_TIME'].dt.date
plant_2['TIME'] = plant_2['DATE_TIME'].dt.time

plant_2.sample(10)
# Out:
#                 DATE_TIME       SOURCE_KEY    DC_POWER    AC_POWER  \
# 65608 2020-06-17 00:15:00  4UPUqMRk7TRMgml    0.000000    0.000000
# 23087 2020-05-27 10:30:00  PeE6FRyGXUgsRhN    0.000000    0.000000
# 208   2020-05-15 02:15:00  Qf4GUc1pJu5T6c6    0.000000    0.000000
# 31739 2020-05-31 22:45:00  Quc1TzYxW2pYoWX    0.000000    0.000000
# 25650 2020-05-28 22:00:00  q49J1IKaHRwDQnt    0.000000    0.000000
# 40181 2020-06-04 23:15:00  LYwnQax7tkwH5Cb    0.000000    0.000000
# 45655 2020-06-07 13:30:00  81aHJ1q11NBPMrL    0.000000    0.000000
# 45144 2020-06-07 07:30:00  rrq4fwE8jgrTyWY  194.440000  190.513333
# 33353 2020-06-01 17:00:00  vOuJvMaM2sgwLmb   81.966667   79.580000
# 32377 2020-06-01 06:00:00  Quc1TzYxW2pYoWX    3.400000    3.286667
#
#        DAILY_YIELD   TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 65608  3336.000000  2.649049e+06            24.140737           23.967333
# 23087  1887.000000  1.348431e+09            32.069014           51.588497
# 208       0.000000  8.384214e+08            26.226078           24.559481
# 31739  5399.000000  3.295842e+08            25.097928           24.769026
# 25650  7799.000000  4.227220e+05            28.640241           27.478934
# 40181  2885.000000  1.795063e+09            24.212599           23.096634
# 45655  1079.000000  1.215427e+09            33.601204           53.343462
# 45144   116.533333  1.210849e+08            24.664388           27.797248
# 33353  4245.066667  2.337453e+06            24.985780           25.354852
# 32377     0.066667  3.295842e+08            23.470155           22.829620
#
#        IRRADIATION        DATE      TIME
# 65608     0.000000  2020-06-17  00:15:00
# 23087     0.866850  2020-05-27  10:30:00
# 208       0.000000  2020-05-15  02:15:00
# 31739     0.000000  2020-05-31  22:45:00
# 25650     0.000000  2020-05-28  22:00:00
# 40181     0.000000  2020-06-04  23:15:00
# 45655     0.710656  2020-06-07  13:30:00
# 45144     0.146790  2020-06-07  07:30:00
# 33353     0.052681  2020-06-01  17:00:00
# 32377     0.006392  2020-06-01  06:00:00

# %%
# Put the Inverter Efficiency in the column

# Define the equation with Unicode symbols
equation = "𝑖𝑁𝑉𝐸𝑅𝑇𝐸𝑅 𝐸𝐹𝐹𝐼𝐶𝐼𝐸𝑁𝐶𝑌 =  (𝐴𝐶 𝑃𝑜𝑤𝑒𝑟 𝑂𝑢𝑡𝑝𝑢𝑡 / 𝐷𝐶 𝑃𝑜𝑤𝑒𝑟 𝐼𝑛𝑝𝑢𝑡)  x 100"

# Print the equation
print(equation)
# Out:
# 𝑖𝑁𝑉𝐸𝑅𝑇𝐸𝑅 𝐸𝐹𝐹𝐼𝐶𝐼𝐸𝑁𝐶𝑌 =  (𝐴𝐶 𝑃𝑜𝑤𝑒𝑟 𝑂𝑢𝑡𝑝𝑢𝑡 / 𝐷𝐶 𝑃𝑜𝑤𝑒𝑟 𝐼𝑛𝑝𝑢𝑡)  x 100

# %%
# Calculate Inverter Efficiency
plant_2['INVERTER_EFFICIENCY'] = (plant_2['AC_POWER'] / plant_2['DC_POWER']) * 100

# Define a function to determine health status
def determine_health_status(efficiency):
    if efficiency >= 80:
        return 'Healthy'
    else:
        return 'Unhealthy'

# Apply the function to create a new column 'HEALTH_STATUS'
plant_2['INVERTER_EFFICIENCY_STATUS'] = plant_2['INVERTER_EFFICIENCY'].apply(determine_health_status)

plant_2.sample(10)
# Out:
#                 DATE_TIME       SOURCE_KEY    DC_POWER    AC_POWER  \
# 56330 2020-06-12 14:45:00  LlT2YUhhzqhg5Sw  502.640000  492.753333
# 2790  2020-05-16 07:45:00  rrq4fwE8jgrTyWY  387.133333  380.140000
# 24571 2020-05-28 07:00:00  rrq4fwE8jgrTyWY  151.746667  148.113333
# 27805 2020-05-30 02:00:00  oZ35aAeoifZaQzV    0.000000    0.000000
# 59838 2020-06-14 06:30:00  oZZkBaNadn6DNKz   97.333333   94.560000
# 34200 2020-06-02 03:00:00  NgDl19wMapZy17u    0.000000    0.000000
# 15625 2020-05-23 02:45:00  rrq4fwE8jgrTyWY    0.000000    0.000000
# 65446 2020-06-16 22:15:00  mqwcsP2rE7J0TFp    0.000000    0.000000
# 53067 2020-06-11 01:30:00  xoJJ8DcxJEcupym    0.000000    0.000000
# 25904 2020-05-29 01:30:00  vOuJvMaM2sgwLmb    0.000000    0.000000
#
#        DAILY_YIELD   TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 56330  3459.866667  2.827618e+08            26.675744           33.730433
# 2790    305.666667  1.209699e+08            27.765505           34.279351
# 24571    73.800000  1.210362e+08            25.183908           26.435457
# 27805     0.000000  1.660083e+09            24.034277           23.420101
# 59838    25.266667  1.708272e+09            24.570349           24.796715
# 34200     0.000000  1.116488e+08            23.054548           22.202293
# 15625     0.000000  1.210106e+08            25.415001           23.583282
# 65446  5606.000000  5.938108e+08            24.013481           23.690346
# 53067  3971.000000  2.092968e+08            24.663322           23.416264
# 25904     0.000000  2.315016e+06            26.225069           24.945128
#
#        IRRADIATION        DATE      TIME  INVERTER_EFFICIENCY  \
# 56330     0.329805  2020-06-12  14:45:00            98.033052
# 2790      0.305885  2020-05-16  07:45:00            98.193559
# 24571     0.123637  2020-05-28  07:00:00            97.605659
# 27805     0.000000  2020-05-30  02:00:00                  NaN
# 59838     0.067979  2020-06-14  06:30:00            97.150685
# 34200     0.000000  2020-06-02  03:00:00                  NaN
# 15625     0.000000  2020-05-23  02:45:00                  NaN
# 65446     0.000000  2020-06-16  22:15:00                  NaN
# 53067     0.000000  2020-06-11  01:30:00                  NaN
# 25904     0.000000  2020-05-29  01:30:00                  NaN
#
#       INVERTER_EFFICIENCY_STATUS
# 56330                    Healthy
# 2790                     Healthy
# 24571                    Healthy
# 27805                  Unhealthy
# 59838                    Healthy
# 34200                  Unhealthy
# 15625                  Unhealthy
# 65446                  Unhealthy
# 53067                  Unhealthy
# 25904                  Unhealthy

# %% [markdown]
# Inverter Efficiency: This can be calculated by dividing the AC_POWER (amount of electricity generated by the inverter) by the DC_POWER (amount of electricity generated by the solar panels) for a given time period. Higher solar panel efficiency indicates that the solar panels are able to convert more sunlight into electricity efficiently.

# %%
#Rearrange the column

plant_2 = plant_2[['DATE_TIME', 'DATE', 'TIME', 'SOURCE_KEY', 'DC_POWER', 'AC_POWER','INVERTER_EFFICIENCY','INVERTER_EFFICIENCY_STATUS', 'DAILY_YIELD', 'TOTAL_YIELD', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']]
plant_2.sample(10)
# Out:
#                 DATE_TIME        DATE      TIME       SOURCE_KEY    DC_POWER  \
# 27383 2020-05-29 21:15:00  2020-05-29  21:15:00  Quc1TzYxW2pYoWX    0.000000
# 16844 2020-05-23 19:45:00  2020-05-23  19:45:00  V94E5Ben1TlhnDV    0.000000
# 56023 2020-06-12 11:15:00  2020-06-12  11:15:00  Mx2yZCDsyf6DPfv  820.520000
# 1319  2020-05-15 14:45:00  2020-05-15  14:45:00  xoJJ8DcxJEcupym    0.000000
# 632   2020-05-15 07:00:00  2020-05-15  07:00:00  oZZkBaNadn6DNKz  312.800000
# 23430 2020-05-27 15:15:00  2020-05-27  15:15:00  Qf4GUc1pJu5T6c6  880.933333
# 45844 2020-06-07 15:30:00  2020-06-07  15:30:00  mqwcsP2rE7J0TFp  165.560000
# 54451 2020-06-11 17:15:00  2020-06-11  17:15:00  vOuJvMaM2sgwLmb   94.480000
# 36974 2020-06-03 10:30:00  2020-06-03  10:30:00  Qf4GUc1pJu5T6c6  484.785714
# 31480 2020-05-31 19:45:00  2020-05-31  19:45:00  oZZkBaNadn6DNKz    0.000000
#
#          AC_POWER  INVERTER_EFFICIENCY INVERTER_EFFICIENCY_STATUS  \
# 27383    0.000000                  NaN                  Unhealthy
# 16844    0.000000                  NaN                  Unhealthy
# 56023  802.860000            97.847706                    Healthy
# 1319     0.000000                  NaN                  Unhealthy
# 632    307.326667            98.250213                    Healthy
# 23430  861.906667            97.840170                    Healthy
# 45844  162.013333            97.857776                    Healthy
# 54451   91.800000            97.163421                    Healthy
# 36974  475.450000            98.074260                    Healthy
# 31480    0.000000                  NaN                  Unhealthy
#
#        DAILY_YIELD   TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 27383  4046.000000  3.295749e+08            30.055038           28.956929
# 16844  9483.000000  1.412150e+09            33.057946           31.095171
# 56023  1521.066667  2.661180e+06            27.978458           38.802913
# 1319   1735.000000  2.091453e+08            37.216598           49.365876
# 632      98.066667  1.708083e+09            25.673202           28.674707
# 23430  8147.466667  8.385220e+08            36.570191           52.363867
# 45844  1346.400000  2.375031e+08            34.035281           49.243574
# 54451  3831.933333  2.392863e+06            26.459341           27.310375
# 36974  1641.142857  8.385633e+08            27.733159           33.867574
# 31480  6617.000000  1.708197e+09            25.926261           23.717882
#
#        IRRADIATION
# 27383     0.000000
# 16844     0.000000
# 56023     0.525934
# 1319      0.686647
# 632       0.199450
# 23430     0.602623
# 45844     0.569397
# 54451     0.061115
# 36974     0.288473
# 31480     0.001228

# %%
# Filter rows with NaN INVERTER_EFFICIENCY and non-zero AC_POWER and DC_POWER
filtered_df = plant_2[(plant_2['INVERTER_EFFICIENCY'].isna()) & (plant_2['AC_POWER'] != 0) & (plant_2['DC_POWER'] != 0)]

# Display the filtered dataframe
print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [DATE_TIME, DATE, TIME, SOURCE_KEY, DC_POWER, AC_POWER, INVERTER_EFFICIENCY, INVERTER_EFFICIENCY_STATUS, DAILY_YIELD, TOTAL_YIELD, AMBIENT_TEMPERATURE, MODULE_TEMPERATURE, IRRADIATION]
# Index: []

# %%
#so just replace NaN value in SOLAR_PANEL_EFFICIENCY column with zero


plant_2['INVERTER_EFFICIENCY'] = plant_2['INVERTER_EFFICIENCY'].fillna(0)
plant_2.sample(5)
# Out:
#                 DATE_TIME        DATE      TIME       SOURCE_KEY    DC_POWER  \
# 63153 2020-06-15 20:15:00  2020-06-15  20:15:00  PeE6FRyGXUgsRhN    0.000000
# 21895 2020-05-26 18:00:00  2020-05-26  18:00:00  Et9kgGMDl729KT4   43.206667
# 17702 2020-05-24 07:45:00  2020-05-24  07:45:00  LYwnQax7tkwH5Cb  418.006667
# 59650 2020-06-14 04:30:00  2020-06-14  04:30:00  IQ2d7wF4YD8zU1Q    0.000000
# 22233 2020-05-26 22:30:00  2020-05-26  22:30:00  xoJJ8DcxJEcupym    0.000000
#
#          AC_POWER  INVERTER_EFFICIENCY INVERTER_EFFICIENCY_STATUS  \
# 63153    0.000000             0.000000                  Unhealthy
# 21895   41.773333            96.682611                    Healthy
# 17702  410.566667            98.220124                    Healthy
# 59650    0.000000             0.000000                  Unhealthy
# 22233    0.000000             0.000000                  Unhealthy
#
#        DAILY_YIELD   TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 63153  2801.000000  1.348540e+09            25.380932           24.375513
# 21895  8268.933333  1.762353e+06            33.863880           33.452122
# 17702   311.333333  1.795004e+09            27.691248           33.951618
# 59650  3023.000000  2.016139e+07            24.161246           23.494035
# 22233  6233.000000  2.092109e+08            28.909453           27.651864
#
#        IRRADIATION
# 63153     0.000000
# 21895     0.031322
# 17702     0.345086
# 59650     0.000000
# 22233     0.000000

# %%
# Create a mapping of 'INVERTER_EFFICIENCY_STATUS' values to corresponding binary values
efficiency_status_mapping = {'Healthy': 1, 'Unhealthy': 0}

# Apply the mapping to create a new column 'EFFICIENCY_STATUS_BINARY' in the DataFrame
plant_2['INVERTER_EFFICIENCY_STATUS_BINARY'] = plant_2['INVERTER_EFFICIENCY_STATUS'].map(efficiency_status_mapping)


plant_2 = plant_2[['DATE_TIME', 'DATE', 'TIME', 'SOURCE_KEY', 'DC_POWER', 'AC_POWER','INVERTER_EFFICIENCY','INVERTER_EFFICIENCY_STATUS','INVERTER_EFFICIENCY_STATUS_BINARY', 'DAILY_YIELD', 'TOTAL_YIELD', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']]
plant_2.sample(5)
# Out:
#                 DATE_TIME        DATE      TIME       SOURCE_KEY  DC_POWER  \
# 27708 2020-05-30 01:00:00  2020-05-30  01:00:00  LlT2YUhhzqhg5Sw       0.0
# 60900 2020-06-14 18:45:00  2020-06-14  18:45:00  4UPUqMRk7TRMgml       0.0
# 55549 2020-06-12 05:45:00  2020-06-12  05:45:00  q49J1IKaHRwDQnt       0.0
# 43287 2020-06-06 10:30:00  2020-06-06  10:30:00  PeE6FRyGXUgsRhN       0.0
# 38580 2020-06-04 05:00:00  2020-06-04  05:00:00  Qf4GUc1pJu5T6c6       0.0
#
#        AC_POWER  INVERTER_EFFICIENCY INVERTER_EFFICIENCY_STATUS  \
# 27708       0.0                  0.0                  Unhealthy
# 60900       0.0                  0.0                  Unhealthy
# 55549       0.0                  0.0                  Unhealthy
# 43287       0.0                  0.0                  Unhealthy
# 38580       0.0                  0.0                  Unhealthy
#
#        INVERTER_EFFICIENCY_STATUS_BINARY  DAILY_YIELD   TOTAL_YIELD  \
# 27708                                  0          0.0  2.826979e+08
# 60900                                  0       1868.0  2.641320e+06
# 55549                                  0          0.0  4.867550e+05
# 43287                                  0        861.0  1.348486e+09
# 38580                                  0          0.0  8.385677e+08
#
#        AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 27708            26.929975           26.396812     0.000000
# 60900            26.370777           26.324486     0.001638
# 55549            23.308441           22.930192     0.000729
# 43287            30.914837           52.225211     0.904774
# 38580            23.291529           22.052189     0.000000

# %%
# Since the dataset is located at India, so just let the time based on India as well

import datetime
import pytz

# Define the local time zone for India
tz = pytz.timezone('Asia/Kolkata')

# Loop through the rows of the DataFrame
for index, row in plant_2.iterrows():
    # Get the date and time from the 'DATE_TIME' column
    date_time = row['DATE_TIME']
    
    # Convert the date and time to the local time zone
    date_time = tz.localize(date_time)
    
    # Get the sunrise and sunset times for the date
    sunrise = date_time.replace(hour=5, minute=30, second=0)
    sunset = date_time.replace(hour=18, minute=30, second=0)
    
    # Compare the date and time with sunrise and sunset times to determine if it's day or night
    if sunrise <= date_time <= sunset:
        plant_2.at[index, 'TIME_OF_DAY'] = 'Day'
    else:
        plant_2.at[index, 'TIME_OF_DAY'] = 'Night'

# %%
plant_2 = plant_2[['DATE_TIME', 'DATE', 'TIME','TIME_OF_DAY', 'SOURCE_KEY', 'DC_POWER', 'AC_POWER','INVERTER_EFFICIENCY','INVERTER_EFFICIENCY_STATUS','INVERTER_EFFICIENCY_STATUS_BINARY', 'DAILY_YIELD', 'TOTAL_YIELD', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']]
plant_2.sample(5)
# Out:
#                 DATE_TIME        DATE      TIME TIME_OF_DAY       SOURCE_KEY  \
# 9824  2020-05-19 15:45:00  2020-05-19  15:45:00         Day  V94E5Ben1TlhnDV
# 60865 2020-06-14 18:15:00  2020-06-14  18:15:00         Day  PeE6FRyGXUgsRhN
# 20021 2020-05-25 16:00:00  2020-05-25  16:00:00         Day  81aHJ1q11NBPMrL
# 19300 2020-05-25 06:00:00  2020-05-25  06:00:00         Day  4UPUqMRk7TRMgml
# 16194 2020-05-23 10:45:00  2020-05-23  10:45:00         Day  Qf4GUc1pJu5T6c6
#
#           DC_POWER     AC_POWER  INVERTER_EFFICIENCY  \
# 9824     80.428571    78.192857            97.220249
# 60865    57.740000    55.900000            96.813301
# 20021   687.120000   672.966667            97.940195
# 19300    18.453333    17.793333            96.423410
# 16194  1238.866667  1207.900000            97.500404
#
#       INVERTER_EFFICIENCY_STATUS  INVERTER_EFFICIENCY_STATUS_BINARY  \
# 9824                     Healthy                                  1
# 60865                    Healthy                                  1
# 20021                    Healthy                                  1
# 19300                    Healthy                                  1
# 16194                    Healthy                                  1
#
#        DAILY_YIELD   TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 9824   6652.214286  1.412117e+09            24.552743           24.526308
# 60865  7197.000000  1.348537e+09            26.174056           27.168484
# 20021  8322.666667  1.215345e+09            37.872446           50.334699
# 19300     1.800000  2.497603e+06            25.074771           23.767201
# 16194  3038.533333  8.384843e+08            33.529897           55.785481
#
#        IRRADIATION
# 9824      0.044119
# 60865     0.040750
# 20021     0.474816
# 19300     0.013541
# 16194     0.922739

# %% [markdown]
# It was decided that India had two time zones: Calcutta (now Kolkata) would use the 90th meridian east and Bombay (now Mumbai) the 75th meridian east.

# %%
plant_2['DAY'] = pd.to_datetime(plant_2['DATE_TIME']).dt.day
plant_2['MONTH'] = pd.to_datetime(plant_2['DATE_TIME']).dt.month
plant_2['WEEK'] = pd.to_datetime(plant_2['DATE_TIME']).dt.week
# add hours and minutes for ml models
plant_2['HOURS'] = pd.to_datetime(plant_2['TIME'],format='%H:%M:%S').dt.hour
plant_2['MINUTES'] = pd.to_datetime(plant_2['TIME'],format='%H:%M:%S').dt.minute
plant_2['TOTAL MINUTES PASS'] = plant_2['MINUTES'] + plant_2['HOURS']*60

# add date as string column
plant_2["DATE_STRING"] = plant_2["DATE"].astype(str) # add column with date as string
plant_2["HOURS"] = plant_2["HOURS"].astype(str)
plant_2["TIME"] = plant_2["TIME"].astype(str)

plant_2 = plant_2[['DATE_TIME', 'DATE', 'TIME','DAY','MONTH','WEEK','HOURS','MINUTES','TOTAL MINUTES PASS','DATE_STRING','TIME_OF_DAY', 'SOURCE_KEY', 'DC_POWER', 'AC_POWER','INVERTER_EFFICIENCY','INVERTER_EFFICIENCY_STATUS','INVERTER_EFFICIENCY_STATUS_BINARY', 'DAILY_YIELD', 'TOTAL_YIELD', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']]
plant_2.sample(5)
# Out:
#                 DATE_TIME        DATE      TIME  DAY  MONTH  WEEK HOURS  \
# 4123  2020-05-16 23:00:00  2020-05-16  23:00:00   16      5    20    23
# 43363 2020-06-06 11:15:00  2020-06-06  11:15:00    6      6    23    11
# 21759 2020-05-26 16:00:00  2020-05-26  16:00:00   26      5    22    16
# 14235 2020-05-22 07:30:00  2020-05-22  07:30:00   22      5    21     7
# 4980  2020-05-17 08:45:00  2020-05-17  08:45:00   17      5    20     8
#
#        MINUTES  TOTAL MINUTES PASS DATE_STRING  ...     DC_POWER     AC_POWER  \
# 4123         0                1380  2020-05-16  ...     0.000000     0.000000
# 43363       15                 675  2020-06-06  ...  1246.620000  1215.826667
# 21759        0                 960  2020-05-26  ...   685.266667   671.180000
# 14235       30                 450  2020-05-22  ...   418.464286   411.050000
# 4980        45                 525  2020-05-17  ...   635.200000   622.271429
#
#        INVERTER_EFFICIENCY  INVERTER_EFFICIENCY_STATUS  \
# 4123              0.000000                   Unhealthy
# 43363            97.529854                     Healthy
# 21759            97.944353                     Healthy
# 14235            98.228215                     Healthy
# 4980             97.964646                     Healthy
#
#        INVERTER_EFFICIENCY_STATUS_BINARY  DAILY_YIELD   TOTAL_YIELD  \
# 4123                                   0  2974.000000  1.348363e+09
# 43363                                  1  3383.400000  2.359912e+06
# 21759                                  1  8710.066667  1.817930e+08
# 14235                                  1   257.500000  1.817536e+08
# 4980                                   1   731.142857  1.115306e+08
#
#        AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 4123             27.528521           27.186144     0.000000
# 43363            31.713857           50.969322     0.966507
# 21759            35.932344           46.234042     0.452363
# 14235            25.862897           31.228512     0.331571
# 4980             29.988077           45.068606     0.470911
#
# [5 rows x 22 columns]

# %% [markdown]
# # EDA

# %%
columns_of_interest = ['DATE_TIME', 'DATE', 'TIME', 'SOURCE_KEY', 'DC_POWER', 'AC_POWER', 'INVERTER_EFFICIENCY',
                       'INVERTER_EFFICIENCY_STATUS', 'DAILY_YIELD', 'TOTAL_YIELD',
                       'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION']

plant_2_ = plant_2[columns_of_interest]

# %%
# Get the number of rows and columns in the DataFrame
num_rows = plant_2_.shape[0]
num_columns = plant_2_.shape[1]

# Print the number of rows and columns
print("Number of rows: ", num_rows)
print("Number of columns: ", num_columns)
# Out:
# Number of rows:  67698
# Number of columns:  13

# %%
plant_2_.info() # Get data types and non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67698 entries, 0 to 67697
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DATE_TIME                   67698 non-null  datetime64[ns]
#  1   DATE                        67698 non-null  object
#  2   TIME                        67698 non-null  object
#  3   SOURCE_KEY                  67698 non-null  object
#  4   DC_POWER                    67698 non-null  float64
#  5   AC_POWER                    67698 non-null  float64
#  6   INVERTER_EFFICIENCY         67698 non-null  float64
#  7   INVERTER_EFFICIENCY_STATUS  67698 non-null  object
#  8   DAILY_YIELD                 67698 non-null  float64
#  9   TOTAL_YIELD                 67698 non-null  float64
#  10  AMBIENT_TEMPERATURE         67698 non-null  float64
#  11  MODULE_TEMPERATURE          67698 non-null  float64
#  12  IRRADIATION                 67698 non-null  float64
# dtypes: datetime64[ns](1), float64(8), object(4)
# memory usage: 9.2+ MB

# %%
plant_2_.describe() # Get general statistics of the columns
# Out:
#            DC_POWER      AC_POWER  INVERTER_EFFICIENCY   DAILY_YIELD  \
# count  67698.000000  67698.000000         67698.000000  67698.000000
# mean     246.701961    241.277825            46.224361   3294.890295
# std      370.569597    362.112118            48.771792   2919.448386
# min        0.000000      0.000000             0.000000      0.000000
# 25%        0.000000      0.000000             0.000000    272.750000
# 50%        0.000000      0.000000             0.000000   2911.000000
# 75%      446.591667    438.215000            97.818279   5534.000000
# max     1420.933333   1385.420000           100.831967   9873.000000
#
#         TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE   IRRADIATION
# count  6.769800e+04         67698.000000        67698.000000  67698.000000
# mean   6.589448e+08            27.986756           32.607233      0.229204
# std    7.296678e+08             4.021294           11.226446      0.309365
# min    0.000000e+00            20.942385           20.265123      0.000000
# 25%    1.996494e+07            24.570349           23.685627      0.000000
# 50%    2.826276e+08            26.910352           27.433723      0.018554
# 75%    1.348495e+09            30.912601           40.019036      0.431027
# max    2.247916e+09            39.181638           66.635953      1.098766

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation coefficients
correlation = plant_2_.corr()

# Set the size of the figure
plt.figure(figsize=(12, 10))

# Heatmap of correlation coefficients
sns.heatmap(correlation, annot=True, cmap='coolwarm')

# Show the plot
plt.show()

# Set threshold for correlation coefficients
threshold = 0.7

# Extract pairs of variables with high positive correlation
high_pos_corr = correlation[correlation > threshold]
high_pos_corr = high_pos_corr[high_pos_corr < 1.0].dropna(how='all')

# Extract pairs of variables with high negative correlation
high_neg_corr = correlation[correlation < -threshold]
high_neg_corr = high_neg_corr[high_neg_corr > -1.0].dropna(how='all')

# Print pairs of variables with high positive correlation
print("Pairs of variables with high positive correlation:")
if high_pos_corr.empty:
    print("NaN")
else:
    for col in high_pos_corr.columns:
        high_corr_vars = high_pos_corr[high_pos_corr[col].notnull()].index.tolist()
        if len(high_corr_vars) > 1:
            print(f"Variable '{col}' has high positive correlation with:")
            print(", ".join(high_corr_vars))
            print()

# Print pairs of variables with high negative correlation
print("Pairs of variables with high negative correlation:")
if high_neg_corr.empty:
    print("NaN")
else:
    for col in high_neg_corr.columns:
        high_corr_vars = high_neg_corr[high_neg_corr[col].notnull()].index.tolist()
        if len(high_corr_vars) > 1:
            print(f"Variable '{col}' has high negative correlation with:")
            print(", ".join(high_corr_vars))
            print()
# Out:
# Pairs of variables with high positive correlation:
# Variable 'DC_POWER' has high positive correlation with:
# AC_POWER, INVERTER_EFFICIENCY, MODULE_TEMPERATURE, IRRADIATION
#
# Variable 'AC_POWER' has high positive correlation with:
# DC_POWER, INVERTER_EFFICIENCY, MODULE_TEMPERATURE, IRRADIATION
#
# Variable 'INVERTER_EFFICIENCY' has high positive correlation with:
# DC_POWER, AC_POWER
#
# Variable 'MODULE_TEMPERATURE' has high positive correlation with:
# DC_POWER, AC_POWER, AMBIENT_TEMPERATURE, IRRADIATION
#
# Variable 'IRRADIATION' has high positive correlation with:
# DC_POWER, AC_POWER, MODULE_TEMPERATURE
#
# Pairs of variables with high negative correlation:
# NaN

# %% [markdown]
# Inverter efficiency is a critical factor in solar power generation, as it directly affects the conversion of DC power from solar panels to AC power that can be fed into the grid. Understanding the performance of inverter systems and identifying any variability in their efficiency is essential for optimizing the overall power generation process.

# %%
#  Multiple Plotting of INVERTER_EFFICIENCY generation on per day basis.

solar_efficiency = plant_2.pivot_table(values='INVERTER_EFFICIENCY', index='TIME', columns='DATE')

def Daywise_plot(data= None, row = None, col = None, title='INVERTER_EFFICIENCY'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='red')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='blue')
        
Daywise_plot(data=solar_efficiency, row=12, col=3)

# %% [markdown]
# The analysis of the inverter efficiency data revealed noticeable fluctuations on a per-day basis. Several days showed significant variability in inverter efficiency, with fluctuations ranging from low to high levels.Only on 2020-06-17 showed the inverter efficiency stability. The variability was observed across different time per day, indicating that inverter efficiency was not consistent and could be influenced by various factors.

# %% [markdown]
# The observed variability in inverter efficiency could be attributed to several factors, such as changing weather conditions, variations in solar irradiation, fluctuations in ambient temperature, equipment performance, and operational conditions. It is crucial for solar power plant operators to monitor and analyze the inverter efficiency data to identify any patterns or trends that may impact power generation performance.

# %%
# Multiple Plotting of IRRADIATION generation on per day basis.

solar_irradiation = plant_2.pivot_table(values='IRRADIATION', index='TIME', columns='DATE')

def Daywise_plot(data= None, row = None, col = None, title='Irradiation'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='red')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='blue')
        
Daywise_plot(data=solar_irradiation, row=12, col=3)

# %% [markdown]
# Inverter Efficiency, which measures the conversion efficiency of DC power from PV panels to AC power for grid consumption, is a crucial performance metric in solar power plants. Irradiation, on the other hand, represents the intensity of sunlight reaching the PV panels and can impact the overall energy generation.

# %% [markdown]
# The analysis indicated that Inverter Efficiency and Irradiation do not exhibit a direct and consistent relationship. While it was expected that higher levels of Irradiation would result in improved Inverter Efficiency, the data revealed that this was not always the case. Some days with sufficient Irradiation levels showed fluctuations in Inverter Efficiency, indicating that other factors may be influencing the performance of the inverters.
#
# This suggests that there may be other variables that impact the Inverter Efficiency, such as temperature, module condition, or other operational factors. Further investigation is warranted to identify these variables and their effects on Inverter Efficiency in order to optimize the performance of the solar power plant.

# %%
#  Multiple Plotting of DC_POWER generation on per day basis.

solar_dc = plant_2.pivot_table(values='DC_POWER', index='TIME', columns='DATE')

def Daywise_plot(data= None, row = None, col = None, title='DC Power'):
    cols = data.columns # take all column
    gp = plt.figure(figsize=(20,40)) 
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols)+1):
        ax = gp.add_subplot(row,col, i)
        data[cols[i-1]].plot(ax=ax, color='red')
        ax.set_title('{} {}'.format(title, cols[i-1]),color='blue')
        
Daywise_plot(data=solar_dc, row=12, col=3)

# %% [markdown]
# Based on this,  'INVERTER_EFFICIENCY' does not appear to be significantly affected by 'IRRADIATION', based on the scatter plot and other visualizations we generated.
#
# However, we observed that 'DC_POWER' has a noticeable impact on 'INVERTER_EFFICIENCY'. As 'DC_POWER' increases, the 'INVERTER_EFFICIENCY' tends to increase as well, indicating a positive relationship between these two variables.
#
# Furthermore, we also noted that 'IRRADIATION' does have an effect on 'DC_POWER', as higher 'IRRADIATION' levels tend to result in higher 'DC_POWER' generation.
#
# This suggests that while 'IRRADIATION' indirectly impacts 'INVERTER_EFFICIENCY' through its effect on 'DC_POWER', it does not have a direct impact on 'INVERTER_EFFICIENCY'

# %%
solar_dc = plant_2.pivot_table(values='DC_POWER', index='TIME', columns='DATE')
solar_ac = plant_2.pivot_table(values='AC_POWER', index='TIME', columns='DATE')

def Daywise_plot(data_dc=None, data_ac=None, row=None, col=None, title_dc='DC Power', title_ac='AC Power'):
    cols_dc = data_dc.columns
    cols_ac = data_ac.columns
    gp = plt.figure(figsize=(20, 40))
    
    gp.subplots_adjust(wspace=0.2, hspace=0.5)
    for i in range(1, len(cols_dc) + 1):
        ax = gp.add_subplot(row, col, i)
        data_dc[cols_dc[i - 1]].plot(ax=ax, color='red', label='DC Power')
        data_ac[cols_ac[i - 1]].plot(ax=ax, color='blue', label='AC Power')
        ax.set_title('{} {} / {}'.format(title_dc, cols_dc[i - 1], title_ac), color='blue')
        ax.legend()

Daywise_plot(data_dc=solar_dc, data_ac=solar_ac, row=12, col=3, title_dc='DC Power', title_ac='AC Power')

# %%
low_efficiency = plant_2[(plant_2['INVERTER_EFFICIENCY'] < 80) & (plant_2['TIME_OF_DAY'] == 'DAY')]
if low_efficiency.empty:
    print("No row effected")
else:
    low_efficiency.sample(10)
# Out:
# No row effected

# %%
low_efficiency = plant_2[(plant_2['INVERTER_EFFICIENCY'] < 80) & (plant_2['AC_POWER'] != 0 ) & (plant_2['DC_POWER'] != 0)]
if low_efficiency.empty:
    print("No row effected")
else:
    low_efficiency.sample(10)
# Out:
# No row effected

# %% [markdown]
# It can be concluded that the inverter appears to be functioning well, as no rows were found to be affected by low inverter efficiency during the day. It seems also there were no row affected due to DC_POWER and AC_POWER are not zero values and INVERTER_EFFICIENCY below than 80%.

# %% [markdown]
# Based on the analysis of the available data, it can be inferred that the inverter is functioning properly as no rows were found to be affected by low inverter efficiency. The observed fluctuations in inverter efficiency are likely attributed to changes in irradiation levels affecting the DC_POWER generation. Further analysis of other factors such as irradiation, DC_POWER, and other environmental conditions may be required to gain a more comprehensive understanding of the performance of the solar power plant.

# %% [markdown]
# As conclusions,
#
# The performance of a solar power plant is influenced by various factors, including irradiation levels, DC_POWER generation, AC_POWER generation, and inverter efficiency. It was observed that changes in irradiation levels affect the DC_POWER generation, which in turn impacts the AC_POWER generation and inverter efficiency. Higher irradiation levels result in increased DC_POWER and AC_POWER generation, leading to higher inverter efficiency. Conversely, lower irradiation levels lead to reduced DC_POWER and AC_POWER generation, resulting in lower inverter efficiency. This highlights the critical role of irradiation levels in determining the performance of a solar power plant and the need for monitoring and optimization of these factors for optimal plant performance.

# %%
print('----- SKEWNESS ------------')
fig, axes = plt.subplots(2, 8, figsize=[25,10])
j = 0
colors = ['#E1728F', '#409E7D']

for i in ['DC_POWER', 'AC_POWER','INVERTER_EFFICIENCY', 'DAILY_YIELD', 'TOTAL_YIELD', 'AMBIENT_TEMPERATURE', 'MODULE_TEMPERATURE', 'IRRADIATION'][:8]:
    sns.histplot(data=plant_2, x=i, kde=True, ax=axes[0,j], hue='INVERTER_EFFICIENCY_STATUS_BINARY', palette=colors)
    sns.boxplot(data=plant_2, x=i, ax=axes[1,j], palette=['#976EBD'])
    j+=1
    print('{} skewness = {}'.format(i, round(plant_2[i].skew(), 2)))
print('---------------------------')
# Out:
# ----- SKEWNESS ------------
# DC_POWER skewness = 1.37
# AC_POWER skewness = 1.37
# INVERTER_EFFICIENCY skewness = 0.11
# DAILY_YIELD skewness = 0.49
# TOTAL_YIELD skewness = 0.75
# AMBIENT_TEMPERATURE skewness = 0.66
# MODULE_TEMPERATURE skewness = 0.98
# IRRADIATION skewness = 1.08
# ---------------------------

# %% [markdown]
# # ORDINAL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

data_scaled = plant_2.copy()

# Create a LabelEncoder object
encoder = LabelEncoder()

# Select the categorical columns to encode
categorical_columns = data_scaled.select_dtypes(include=['object']).columns

# Encode the categorical columns
data_scaled[categorical_columns] = data_scaled[categorical_columns].apply(encoder.fit_transform)

# %% [markdown]
# #  Scaling Data

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler

# Select the columns to scale
columns_to_scale = ['DC_POWER', 'AC_POWER','MODULE_TEMPERATURE','IRRADIATION']

# Create a RobustScaler object
scaler = RobustScaler()

# Fit the scaler to the data and transform the data
data_scaled[columns_to_scale] = scaler.fit_transform(plant_2[columns_to_scale])

# %%
# Select the columns to scale
cols_to_scale = ['INVERTER_EFFICIENCY', 'DAILY_YIELD', 'TOTAL_YIELD','AMBIENT_TEMPERATURE']

# Create an instance of the MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler to the data
scaler.fit(data_scaled[cols_to_scale])

# Transform the data
data_scaled[cols_to_scale] = scaler.transform(data_scaled[cols_to_scale])

# %%
data_scaled.sample(10)
# Out:
#                 DATE_TIME  DATE  TIME  DAY  MONTH  WEEK  HOURS  MINUTES  \
# 23889 2020-05-27 21:30:00    12    86   27      5    22     14       30
# 46497 2020-06-07 23:00:00    23    92    7      6    23     16        0
# 67277 2020-06-17 19:00:00    33    76   17      6    25     11        0
# 57325 2020-06-13 02:00:00    29     8   13      6    24     12        0
# 22977 2020-05-27 09:00:00    12    36   27      5    22     23        0
# 47784 2020-06-08 13:30:00    24    54    8      6    24      5       30
# 59770 2020-06-14 05:45:00    30    23   14      6    24     19       45
# 59373 2020-06-14 01:15:00    30     5   14      6    24      1       15
# 59813 2020-06-14 06:15:00    30    25   14      6    24     20       15
# 21329 2020-05-26 10:00:00    11    40   26      5    22      2        0
#
#        TOTAL MINUTES PASS  DATE_STRING  ...  DC_POWER  AC_POWER  \
# 23889                1290           12  ...  0.000000  0.000000
# 46497                1380           23  ...  0.000000  0.000000
# 67277                1140           33  ...  0.000000  0.000000
# 57325                 120           29  ...  0.000000  0.000000
# 22977                 540           12  ...  1.806691  1.802175
# 47784                 810           24  ...  0.000000  0.000000
# 59770                 345           30  ...  0.000000  0.000000
# 59373                  75           30  ...  0.000000  0.000000
# 59813                 375           30  ...  0.108526  0.106979
# 21329                 600           11  ...  2.439589  2.429842
#
#        INVERTER_EFFICIENCY  INVERTER_EFFICIENCY_STATUS  \
# 23889             0.000000                           1
# 46497             0.000000                           1
# 67277             0.000000                           1
# 57325             0.000000                           1
# 22977             0.970714                           0
# 47784             0.000000                           1
# 59770             0.000000                           1
# 59373             0.000000                           1
# 59813             0.959282                           0
# 21329             0.969259                           0
#
#        INVERTER_EFFICIENCY_STATUS_BINARY  DAILY_YIELD  TOTAL_YIELD  \
# 23889                                  0     0.336574     0.093070
# 46497                                  0     0.791857     0.001171
# 67277                                  0     0.437760     0.001080
# 57325                                  0     0.371518     0.146637
# 22977                                  1     0.105864     0.125749
# 47784                                  0     0.110503     0.053867
# 59770                                  0     0.000000     0.264153
# 59373                                  0     0.651778     0.080914
# 59813                                  1     0.000878     0.080914
# 21329                                  1     0.212695     0.759885
#
#        AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 23889             0.443263            0.032310    -0.043047
# 46497             0.250859           -0.195552    -0.043047
# 67277             0.142855           -0.295954    -0.043047
# 57325             0.088462           -0.364886    -0.043047
# 22977             0.469732            0.911629     1.373004
# 47784             0.687787            1.545115     2.023441
# 59770             0.174696           -0.241659    -0.040811
# 59373             0.174294           -0.238600    -0.043047
# 59813             0.186778           -0.208603     0.036906
# 21329             0.574985            1.355038     1.836130
#
# [10 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = data_scaled.drop(['DATE_TIME', 'DATE', 'TIME','DAY','MONTH','WEEK','HOURS','MINUTES','TOTAL MINUTES PASS','DATE_STRING','TIME_OF_DAY', 'SOURCE_KEY','INVERTER_EFFICIENCY','INVERTER_EFFICIENCY_STATUS','INVERTER_EFFICIENCY_STATUS_BINARY'], axis=1)
y = data_scaled['INVERTER_EFFICIENCY_STATUS_BINARY']

X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=.5,random_state=123)

# %%
# !pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in c:\users\muham\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: tqdm in c:\users\muham\anaconda3\lib\site-packages (from lazypredict) (4.64.0)
# Requirement already satisfied: joblib in c:\users\muham\anaconda3\lib\site-packages (from lazypredict) (1.1.0)
# Requirement already satisfied: scikit-learn in c:\users\muham\anaconda3\lib\site-packages (from lazypredict) (1.0.2)
# Requirement already satisfied: pandas in c:\users\muham\anaconda3\lib\site-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: click in c:\users\muham\anaconda3\lib\site-packages (from lazypredict) (8.0.4)
# Requirement already satisfied: xgboost in c:\users\muham\anaconda3\lib\site-packages (from lazypredict) (1.7.5)
# Requirement already satisfied: lightgbm in c:\users\muham\anaconda3\lib\site-packages (from lazypredict) (3.3.5)
# Requirement already satisfied: colorama in c:\users\muham\anaconda3\lib\site-packages (from click->lazypredict) (0.4.4)
# Requirement already satisfied: scipy in c:\users\muham\anaconda3\lib\site-packages (from lightgbm->lazypredict) (1.7.3)
# Requirement already satisfied: wheel in c:\users\muham\anaconda3\lib\site-packages (from lightgbm->lazypredict) (0.37.1)
# Requirement already satisfied: numpy in c:\users\muham\anaconda3\lib\site-packages (from lightgbm->lazypredict) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\muham\anaconda3\lib\site-packages (from scikit-learn->lazypredict) (2.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\muham\anaconda3\lib\site-packages (from pandas->lazypredict) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\muham\anaconda3\lib\site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\muham\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# Fit the classifier to the data
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

# View the results
print(models)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [16:05<00:00, 33.28s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00     1.00      1.00
# GaussianNB                         1.00               1.00     1.00      1.00
# XGBClassifier                      1.00               1.00     1.00      1.00
# RandomForestClassifier             1.00               1.00     1.00      1.00
# QuadraticDiscriminantAnalysis      1.00               1.00     1.00      1.00
# BaggingClassifier                  1.00               1.00     1.00      1.00
# LGBMClassifier                     1.00               1.00     1.00      1.00
# DecisionTreeClassifier             1.00               1.00     1.00      1.00
# ExtraTreesClassifier               1.00               1.00     1.00      1.00
# ExtraTreeClassifier                1.00               1.00     1.00      1.00
# PassiveAggressiveClassifier        0.99               0.99     0.99      0.99
# Perceptron                         0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.99     0.99      0.99
# SGDClassifier                      0.98               0.98     0.98      0.98
# SVC                                0.98               0.98     0.98      0.98
# LogisticRegression                 0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.98     0.98      0.98
# LabelPropagation                   0.95               0.95     0.95      0.95
# LabelSpreading                     0.95               0.95     0.95      0.95
# CalibratedClassifierCV             0.94               0.93     0.93      0.94
# NuSVC                              0.88               0.87     0.87      0.88
# LinearDiscriminantAnalysis         0.87               0.86     0.86      0.86
# RidgeClassifierCV                  0.87               0.86     0.86      0.86
# RidgeClassifier                    0.86               0.85     0.85      0.86
# BernoulliNB                        0.80               0.80     0.80      0.80
# NearestCentroid                    0.79               0.79     0.79      0.79
# DummyClassifier                    0.53               0.50     0.50      0.36
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.21
# GaussianNB                           0.13
# XGBClassifier                        1.34
# RandomForestClassifier               2.86
# QuadraticDiscriminantAnalysis        0.16
# BaggingClassifier                    0.57
# LGBMClassifier                       0.50
# DecisionTreeClassifier               0.13
# ExtraTreesClassifier                 2.48
# ExtraTreeClassifier                  0.18
# PassiveAggressiveClassifier          0.25
# Perceptron                           0.19
# LinearSVC                            1.73
# SGDClassifier                        0.16
# SVC                                 42.52
# LogisticRegression                   0.62
# KNeighborsClassifier                 3.25
# LabelPropagation                   265.69
# LabelSpreading                     352.14
# CalibratedClassifierCV               3.12
# NuSVC                              284.93
# LinearDiscriminantAnalysis           0.76
# RidgeClassifierCV                    0.18
# RidgeClassifier                      0.19
# BernoulliNB                          0.14
# NearestCentroid                      0.16
# DummyClassifier                      0.09
